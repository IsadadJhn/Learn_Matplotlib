# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Histogram**

# %%
#it is a graph showing the number of observation within each given interval
#grafik yang menunjukkan jumlah pengamatan dari setiap interval yang diberikan

# %%
x = np.random.normal(170,10,250) # 170 = mean , 10 = standard deviation , 250 random numbers
#170 +- 10 = 160-180 = frequency distributions
x
# Out:
# array([184.74652025, 193.44126382, 183.5067298 , 165.17619011,
#        158.4463269 , 176.25626285, 173.44751122, 169.73757757,
#        186.33314611, 174.25827072, 189.36520448, 171.19355355,
#        181.53110551, 157.22547682, 162.31914451, 175.10379225,
#        175.96119921, 161.66460471, 178.60261841, 176.19951544,
#        169.61129618, 182.67491485, 171.58147726, 160.86791684,
#        173.72082291, 159.55538315, 171.77393991, 174.74415662,
#        183.27572904, 185.6470636 , 168.96226851, 172.6768378 ,
#        174.30140868, 170.59142111, 167.9513002 , 171.03147461,
#        159.50665775, 173.77469399, 169.90112552, 158.79870117,
#        173.63411406, 154.68968139, 173.11190014, 164.25664282,
#        188.25518617, 169.23214326, 183.31597064, 177.20950704,
#        163.78378999, 175.27785938, 182.14514663, 171.24461029,
#        149.27951448, 173.46821465, 175.06649348, 167.95714568,
#        164.98588381, 164.15665749, 169.19985061, 175.26794737,
# ...

# %%
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()
